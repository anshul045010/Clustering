# %% [markdown]
# #**Product Sales Segmentation through K-Means Clustering**
# **1. Project Objectives | Problem Statements**
#
# 1.1. PO1 | PS1: Price Optimization for Maximized Profit using Unsupervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters
#
# 1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics
#
# **2. Description of Data**
#
# 2.1. Data Source, Size, Shape
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/kanyianalyst/customer-age-group-segmentation)
#
# 2.1.2. Data Size (11.77 MB)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-12 | Number of Records-113,036 rows × 12 columns)
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable**
#
# Index Variable: Nil in the dataset
#
# 2.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)
#
# 2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type
#
# **Nominal Categories:**
#
# - Age Group
#
# - Customer Gender
#
# - Country
#
# - Product Category
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:** None in this dataset
#
# **2.2.3. Non-Categorical Variables or Features Non-Categorical Variables or Features:**
#
# - Customer Age
#
# - Age Group Number
#
# - Order Quantity
#
# - Unit Cost
#
# - Unit Price
#
# - Profit
#
# - Cost
#
# - Revenue
#
# **Variable Description:**
#
# **Index Variable:**
#
# - Customer Age: Age of the customers who purchased the products
#
# **Categorical Variables:**
#
# **Nominal Categories:**
#
# - Age Group: Customers from different age groups (e.g., Young, Youth, Adult)
#
# - Customer Gender: Gender of the customer (e.g., Male, Female)
#
# - Country: Country (e.g., Canada, Australia, France)
#
# - Product Category: Produts sold (e.g., Bike, Accessories, Clothing)
#
# **Non-Categorical Variables:**
#
# - Customer Age: Age of the customer
#
# - Age Group Number: Number to which age group customer is from
#
# - Order Quantity: Quantity that customer ordered
#
# - Unit Cost: Cost of the product per unit
#
# - Unit Price: Price of the product per unit
#
# - Profit: Profit earned from the customer
#
# - Cost: Total cost of the products sold to customer
#
# - Revenue: Total revenue drom the products sold to customer
#
# **2.3. Descriptive Statistics**
#
# **2.3.1. Descriptive Statistics:** Categorical Variables or Features
#
# **2.3.1.1. Count | Frequency Statistics**
#
# **Count of Unique Values in Categorical Features:**
#
# **Age Group:**
# - Adults (35-64): 55824
# - Young Adults (25-34): 38654
# - Youth (less than 25): 17828
# - Seniors (more than 64):	730
#
# **Customer Gender:**
# - Male:	58312
# - Female:	54724
#
# **Country:**
# - United States:	39206
# - Australia:	23936
# - Canada:	14178
# - United Kingdom:	13620
# - Germany:	11098
# - France:	10998
#
# **Product Category:**
# - Accessories:	70120
# - Bikes:	25982
# - Clothing:	16934
#
#
# **2.3.1.2. Proportion (Relative Frequency) Statistics
# Proportion of Unique Values in Categorical Features:**
#
# **Age Group:**
# - Adults (35-64): 49%
# - Young Adults (25-34): 34%
# - Youth (less than 25): 16%
# - Seniors (more than 64): 1%
#
# **Customer Gender:**
# - Male:	52%
# - Female:	48%
#
# **Country:**
# - United States:	35%
# - Australia: 21%
# - Canada:		13%
# - United Kingdom:	12%
# - Germany:	10%
# - France:		10%
#
# **Product Category:**
# - Accessories:	62%
# - Bikes:	23%
# - Clothing:	15%
#
# **2.3.2. Descriptive Statistics: Non-Categorical Variables or Features**
#
# **2.3.2.1. Measures of Central Tendency**
#
# **Mean:**
# - Customer_Age: 35.92
# - Age_Group_NUMBER: 1.00
# - Order_Quantity: 11.90
# - Unit_Cost: 267.30
# - Unit_Price: 452.94
# - Profit: 372.68
# - Cost: 469.32
# - Revenue: 842.00
#
# **Standard Deviation:**
# - Customer_Age: 11.02
# - Age_Group_NUMBER: 0.00
# - Order_Quantity: 9.56
# - Unit_Cost: 549.84
# - Unit_Price: 922.07
# - Profit: 595.08
# - Cost: 884.87
# - Revenue: 1466.20
#
# **2.3.2.3. Correlation Statistics (with Test of Correlation)**
#
# **Correlation Matrix:**
# - Correlation coefficient (Profit vs. Revenue): 0.9861698395998734
# - Correlation coefficient (Profit vs. Cost): 0.9615517239157476
#
# Summary:
# The dataset comprises 8 variables and 113,036 records.
# Non-categorical variables include 'Customer_Age', 'Age_Group_NUMBER', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', and 'Revenue'.
# Descriptive statistics provide insights into the distribution of data, including count, proportion, mean, standard deviation, and correlation coefficients.
#
# **3.1. Data Pre-Processing**
#
# **3.1.1. Missing Data Statistics and Treatment**
#
# **Variable-wise Missing Data Information:**
#
# No missing data in any variable.
#
# **Record-wise Missing Data Information (Top 5 Records):**
#
# No records with missing data.
#
# **3.1.2. Numerical Encoding of Categorical Variables or Features
# Ordinal Encoder:**
#
# Used to encode categorical variables into numerical format.
#
# **3.1.3. Outlier Statistics and Treatment**
#
# **Outlier Detection:**
#
# Identified outliers using boxplot visualization.
#
# **Treatment:**
#
# Outliers treated by performing normalization using Min-Max Scaler.
#
# **3.1.4. Data Transformation and Scaling**
#
# **Normalization:**
# Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# **3.1.5. Pre-Processed Dataset**
#
# **Pre-Processed Categorical Data Subset:**
#
# Encoded categorical data using Ordinal Encoder.
#
# **Pre-Processed Non-Categorical Data Subset:**
#
# Normalized non-categorical data using Min-Max Scaler.
#
# **Pre-Processed Dataset:**
#
# Merged pre-processed categorical and non-categorical data subsets.
#
# **Note:**
#
# No data bifurcation into training and testing sets was required as part of this analysis.
#
# # **3.2. Data Analysis**
#
# In this section, we conduct a comprehensive analysis of the data using the K-Means clustering algorithm and evaluate its performance using various metrics.
#
# #### **3.2.1. Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance**
#
# K-Means is employed to partition data points into K clusters based on the Euclidean distance metric. The choice of K significantly influences the granularity of the clustering and the interpretability of the results.
#
# #### **3.2.2. Clustering Model Performance Evaluation**
#
# ##### **3.2.2.1. K Means Clustering Using the Elbow Method**
#
# In the Elbow method, we vary the number of clusters (K) from 1 to 10 and calculate WCSS (Within-Cluster Sum of Square) for each value of K. WCSS is the sum of the squared distance between each point and the centroid in a cluster. When plotted against the number of clusters, the plot exhibits an "Elbow" shape. The optimal value of K is identified at the point where the plot shows a significant change in slope before becoming almost parallel to the X-axis.
#
# ##### **3.2.2.2. Silhouette Score | Davies-Bouldin Score (Base Model: K-Means)**
#
# - **Silhouette Score**: Measures the cohesion and separation of clusters, with values ranging from -1 to 1. Higher scores indicate better-defined clusters.
# - **Davies-Bouldin Index**: Measures the average similarity between each cluster and its most similar cluster. Lower values suggest better clustering.
#
# The evaluation is performed for different cluster sizes to identify the optimal number of clusters that maximize the Silhouette Score and minimize the Davies-Bouldin Index.
#
# ##### **3.2.2.3. Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Means)**
#
# - **Time Statistics**: Includes the time taken by the K-Means algorithm to converge for a given number of clusters.
# - **Memory Statistics**: Refers to the memory consumption (CPU or GPU) by the K-Means algorithm during execution.
#
# These statistics offer insights into the computational efficiency and scalability of K-Means for different cluster sizes.
#
# # **Detailed Analysis**
#
# #### K Means Clustering Using the Elbow Method:
#
# - The Elbow method is employed to determine the optimal number of clusters (K) by analyzing the plot of WCSS against the number of clusters.
# - The "Elbow" point on the plot indicates a significant change in slope, suggesting the optimal value of K.
#
# #### Silhouette Score and Davies-Bouldin Index Analysis:
# ```
# Silhouette Score for 2 clusters: 0.8061800224760338
# Davies-Bouldin Index for 2 clusters: 0.5267640419754422
#
# Silhouette Score for 3 clusters: 0.8074866078517091
# Davies-Bouldin Index for 3 clusters: 0.4737064653462755
#
# Silhouette Score for 4 clusters: 0.7775441195350395
# Davies-Bouldin Index for 4 clusters: 0.5941659253186007
#
# Silhouette Score for 5 clusters: 0.6388356234132078
# Davies-Bouldin Index for 5 clusters: 0.6338475735413509
#
# ```
# These metrics aid in determining the optimal number of clusters, balancing cohesion and separation.
#
# ### **Conclusion**
#
# The evaluation of the K-Means clustering model provides valuable insights into the clustering quality and computational efficiency. Based on the metrics analyzed, K=4 is chosen as the optimal number of clusters, ensuring meaningful groupings of data points while maintaining computational scalability. Theoretical insights into the metrics used enhance the understanding of the clustering process and its outcomes, facilitating informed decision-making. Additionally, the Elbow method aids in confirming the optimal value of K, providing a comprehensive approach to cluster analysis.
#
#
# **3.2.3.1.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
#
# Chi-Square Test of Independence for variable 'Age_Group_code':
#    - Chi-Square Value: 209.7395071092572
#    - P-value: 1.600284750425412e-42
# Chi-Square Test of Independence for variable 'Customer_Gender_code':
#    - Chi-Square Value: 42.097943967425365
#    - P-value: 7.220173233870569e-10
# Chi-Square Test of Independence for variable 'Country_code':
#    - Chi-Square Value: 1405.3599713119752
#    - P-value: 6.906444269987827e-296
# Chi-Square Test of Independence for variable 'Product_Category_code':
#    - Chi-Square Value: 68617.98680663857
#    - P-value: 0.0
#
# The Chi-Square Test of Independence results provide insights into the relationship between categorical variables and the cluster labels generated by the clustering algorithm. Here's the analysis:
#
# **Age Group and Cluster Labels**:
#    - The Chi-Square value of 209.74 with an extremely low p-value (1.60e-42) indicates a significant association between age group and cluster labels.
#    - It suggests that customers belonging to different age groups exhibit varying preferences or behaviors, leading to the formation of distinct clusters based on age.
#
# **Customer Gender and Cluster Labels**:
#    - The Chi-Square value of 42.10 with a very low p-value (7.22e-10) suggests a significant association between customer gender and cluster labels.
#    - It indicates that gender may influence customer segmentation, with different clusters representing distinct gender preferences or behaviors.
#
# **Country and Cluster Labels**:
#    - The Chi-Square value of 1405.36 with an extremely low p-value (6.91e-296) indicates a highly significant association between country and cluster labels.
#    - It implies that customers from different countries exhibit diverse preferences or behaviors, leading to the formation of distinct clusters based on geographical location.
#
# **Product Category and Cluster Labels**:
#    - The Chi-Square value of 68617.99 with a p-value of 0.0 indicates an extremely significant association between product category and cluster labels.
#    - It suggests that customers' preferences for different product categories significantly influence their cluster membership, leading to distinct clusters based on product preferences.
#
#
# The Chi-Square Test of Independence results reveal significant associations between categorical variables (age group, gender, country, and product category) and cluster labels, indicating distinct customer segments based on these variables.
#
# #**Managerial Insights:**
#
#
# **Tailored Marketing Strategies**:
#    - **Age Group**: Develop targeted marketing campaigns tailored to different age groups identified in the clusters. For example, promotions and advertisements can be customized to resonate with the preferences and interests of specific age demographics.
#    - **Customer Gender**: Design marketing messages and promotions that appeal to different gender preferences and behaviors. This could involve crafting gender-specific product recommendations or advertising creative.
#    - **Country**: Customize marketing strategies and product offerings based on the preferences and cultural nuances of customers from different countries. Localization efforts can enhance brand perception and customer engagement.
#    - **Product Category**: Tailor marketing initiatives to cater to the preferences and buying behaviors associated with specific product categories. Highlight featured products or promotions based on the predominant preferences within each cluster.
#
# **Product Development and Assortment Planning**:
#    - **Product Category**: Use insights from cluster analysis to prioritize product development efforts and optimize product assortments. Focus on expanding product offerings in categories that are popular among identified clusters to meet customer demand effectively.
#
# **Customer Experience Enhancement**:
#    - **Age Group and Gender**: Customize the customer experience across different touchpoints, including website design, customer service interactions, and loyalty programs, to align with the preferences of diverse customer segments.
#    - **Country**: Offer localized customer support, language options, and shipping policies to provide a seamless and personalized experience for customers in different geographical regions.
#
# **Market Expansion Opportunities**:
#    - **Country**: Identify potential growth markets by analyzing the distribution of clusters across different countries. Explore opportunities to expand operations or launch targeted marketing campaigns in regions with significant clusters of high-potential customers.
#
# **Competitive Positioning**:
#    - Use insights from cluster analysis to differentiate the brand positioning and value proposition in the market. Tailor messaging and branding efforts to resonate with the preferences and values of the target customer segments identified through clustering.
#
# By leveraging the insights gleaned from the significant associations between categorical variables and cluster labels, businesses can refine their marketing strategies, enhance customer experiences, and capitalize on market opportunities to drive growth and competitive advantage.
#
# **3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
# The ANOVA results for each continuous variable across the clusters provide insights into whether there are significant differences in the means of these variables among the clusters. Here's the analysis:
#
# **Customer Age and Age Group Number**:
#    - The ANOVA results indicate that there are no significant differences in customer age and age group number across the clusters. This suggests that the segmentation based on these variables might not be relevant for distinguishing between clusters.
#
# **Order Quantity, Unit Cost, Unit Price, Profit, Cost, and Revenue**:
#    - For these variables, the ANOVA results also show no significant differences in means across the clusters. This implies that the clusters do not exhibit distinct patterns in terms of these metrics. It's possible that these variables do not contribute significantly to the segmentation of customers.
#
# **Min-Max Normalized Variables**:
#    - Similar to the original variables, the min-max normalized versions of these variables also do not show significant differences in means across the clusters. This suggests that normalizing the variables did not alter the lack of distinction between clusters.
#
# Overall, the ANOVA results indicate that the clusters derived from the K-means algorithm do not exhibit significant differences in terms of the analyzed continuous variables. This could imply that the clustering algorithm may not effectively capture meaningful patterns in the data or that the selected variables are not strong discriminators for segmentation. Further analysis or refinement of the clustering approach may be necessary to identify more meaningful clusters.
#
# #**Managerial Insights:**
#
# The ANOVA analysis results, indicating non-significant differences in the means of various continuous variables across different clusters, have several managerial implications:
#
# **Segmentation Relevance**:
#    - The lack of significant differences in customer metrics across clusters suggests that the segmentation approach based on these variables may not effectively capture distinct customer segments. Managers should reassess the segmentation strategy and consider alternative variables or approaches to identify meaningful customer segments.
#
# **Marketing Strategy Adjustment**:
#    - Without clear differentiation between clusters in terms of customer characteristics such as age, order quantity, profit, etc., marketing strategies tailored to specific segments may not be as effective. Managers should adopt more flexible and adaptive marketing strategies that cater to the broader customer base rather than focusing on specific segments.
#
# **Product Development**:
#    - Non-significant differences in variables like unit cost, unit price, revenue, and profit across clusters suggest that customer preferences for products or services may be relatively homogenous. This could inform product development strategies to focus on offerings that appeal to a wider audience rather than niche segments.
#
# **Resource Allocation**:
#    - Resources allocated to customer segmentation initiatives based on these variables may be better utilized elsewhere. Managers should reconsider resource allocation strategies and invest in areas such as customer experience enhancement, product innovation, or market expansion to drive growth and profitability.
#
# **Data Quality and Analysis**:
#    - The ANOVA results may also indicate potential issues with data quality or analysis techniques. Managers should review data collection methods, validate data integrity, and assess the suitability of the chosen statistical techniques. It may be necessary to collect additional data or employ more sophisticated analytical methods to uncover meaningful insights.
#
# **Continuous Monitoring and Adaptation**:
#    - Market dynamics and customer preferences evolve over time. Managers should continuously monitor customer behavior, collect feedback, and adapt segmentation strategies accordingly. Flexibility and agility in responding to changing market conditions are essential for maintaining competitiveness.
#
# Overall, the ANOVA analysis highlights the need for a critical review of segmentation strategies and a proactive approach to addressing customer needs and preferences in a dynamic business environment.

# %%
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
import pandas as pd, numpy as np
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split

# %%
# !pip install pydataset

# %%
df=pd.read_csv('product sales.csv')
df
# Out:
#         Customer_Age             Age_Group  Age_Group_NUMBER Customer_Gender  \
# 0                 17           Youth (<25)                 1               M
# 1                 23           Youth (<25)                 1               M
# 2                 33  Young Adults (25-34)                 1               F
# 3                 39        Adults (35-64)                 1               M
# 4                 42        Adults (35-64)                 1               M
# ...              ...                   ...               ...             ...
# 113031            52        Adults (35-64)                 1               F
# 113032            25  Young Adults (25-34)                 1               F
# 113033            26  Young Adults (25-34)                 1               M
# 113034            33  Young Adults (25-34)                 1               F
# 113035            44        Adults (35-64)                 1               M
#
# ...

# %%
# Dataset Used : df

df.info() # Dataframe Information (Provide Information on Missing Data)
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Customer_Age      113036 non-null  int64
#  1   Age_Group         113036 non-null  object
#  2   Age_Group_NUMBER  113036 non-null  int64
#  3   Customer_Gender   113036 non-null  object
#  4   Country           113036 non-null  object
#  5   Product_Category  113036 non-null  object
#  6   Order_Quantity    113036 non-null  int64
#  7   Unit_Cost         113036 non-null  int64
#  8   Unit_Price        113036 non-null  int64
#  9   Profit            113036 non-null  int64
#  10  Cost              113036 non-null  int64
#  11  Revenue           113036 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 10.3+ MB
# 0        0
# 75353    0
# 75364    0
# 75363    0
# 75362    0
# dtype: int64

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Customer_Age      113036 non-null  int64
#  1   Age_Group         113036 non-null  object
#  2   Age_Group_NUMBER  113036 non-null  int64
#  3   Customer_Gender   113036 non-null  object
#  4   Country           113036 non-null  object
#  5   Product_Category  113036 non-null  object
#  6   Order_Quantity    113036 non-null  int64
#  7   Unit_Cost         113036 non-null  int64
#  8   Unit_Price        113036 non-null  int64
#  9   Profit            113036 non-null  int64
#  10  Cost              113036 non-null  int64
#  11  Revenue           113036 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 10.3+ MB
# None
#         Customer_Age  Age_Group_NUMBER  Order_Quantity      Unit_Cost  \
# ...

# %%
from scipy.stats import pearsonr

# Calculate the correlation coefficient and p-value for Profit vs. Revenue
corr_profit_revenue, p_value_profit_revenue = pearsonr(df['Profit'], df['Revenue'])
print("Correlation coefficient (Profit vs. Revenue):", corr_profit_revenue)
print("p-value (Profit vs. Revenue):", p_value_profit_revenue)

# Calculate the correlation coefficient and p-value for Profit vs. Cost
corr_profit_cost, p_value_profit_cost = pearsonr(df['Profit'], df['Cost'])
print("Correlation coefficient (Profit vs. Cost):", corr_profit_cost)
print("p-value (Profit vs. Cost):", p_value_profit_cost)
# Out:
# Correlation coefficient (Profit vs. Revenue): 0.9861698395998734
# p-value (Profit vs. Revenue): 0.0
# Correlation coefficient (Profit vs. Cost): 0.9615517239157476
# p-value (Profit vs. Cost): 0.0

# %%
# Data Bifurcation
df_cat = df[['Age_Group','Customer_Gender','Country','Product_Category']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Customer_Age','Age_Group_NUMBER','Order_Quantity','Unit_Cost','Unit_Price','Profit','Cost','Revenue']] # Non-Categorical Data

# %%
# Using Scikit Learn : Ordinal Encoder (Superior)
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Age_Group_code','Customer_Gender_code','Country_code','Product_Category_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#                    Age_Group Customer_Gender         Country Product_Category  \
# 0                Youth (<25)               M          canada            Bikes
# 1                Youth (<25)               M       Australia            Bikes
# 2       Young Adults (25-34)               F          France            Bikes
# 3             Adults (35-64)               M   United States            Bikes
# 4             Adults (35-64)               M   United States            Bikes
# ...                      ...             ...             ...              ...
# 113031        Adults (35-64)               F  United Kingdom            Bikes
# 113032  Young Adults (25-34)               F         Germany            Bikes
# 113033  Young Adults (25-34)               M       Australia            Bikes
# 113034  Young Adults (25-34)               F       Australia            Bikes
# 113035        Adults (35-64)               M       Australia            Bikes
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_noncat is your DataFrame and contains the columns mentioned

# Set the overall figure size
plt.figure(figsize=(12, 10))

# Create boxplots for each non-categorical variable
variables = ['Customer_Age', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']

for i, var in enumerate(variables, start=1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=df_noncat[var])
    plt.title(f'Boxplot of {var}')
    plt.ylabel(var)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat [['Customer_Age','Age_Group_NUMBER','Order_Quantity','Unit_Cost','Unit_Price','Profit','Cost','Revenue']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['Customer_Age_mmnorm','Age_Group_NUMBER_mmnorm','Order_Quantity_mmnorm','Unit_Cost_mmnorm','Unit_Price_mmnorm','Profit_mmnorm','Cost_mmnorm','Revenue_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#         Customer_Age  Age_Group_NUMBER  Order_Quantity  Unit_Cost  Unit_Price  \
# 0                 17                 1               2       1519        2443
# 1                 23                 1               2       1252        2295
# 2                 33                 1               2       2171        3578
# 3                 39                 1               2        713        1120
# 4                 42                 1               2        344         540
# ...              ...               ...             ...        ...         ...
# 113031            52                 1               2       1555        2443
# 113032            25                 1               1        713        1120
# 113033            26                 1               1        713        1120
# 113034            33                 1               1       1252        2295
# 113035            44                 1               1        713        1120
#
# ...

# %%
# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]
# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
#df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#                    Age_Group Customer_Gender         Country Product_Category  \
# 0                Youth (<25)               M          canada            Bikes
# 1                Youth (<25)               M       Australia            Bikes
# 2       Young Adults (25-34)               F          France            Bikes
# 3             Adults (35-64)               M   United States            Bikes
# 4             Adults (35-64)               M   United States            Bikes
# ...                      ...             ...             ...              ...
# 113031        Adults (35-64)               F  United Kingdom            Bikes
# 113032  Young Adults (25-34)               F         Germany            Bikes
# 113033  Young Adults (25-34)               M       Australia            Bikes
# 113034  Young Adults (25-34)               F       Australia            Bikes
# 113035        Adults (35-64)               M       Australia            Bikes
#
# ...

# %% [markdown]
# # DATA PRE PROCESSING
#
# ## Objective:
#
# The objective of this data preprocessing exercise is to prepare the dataset for further analysis and modeling by encoding categorical variables using the Ordinal Encoder, standardizing non-categorical variables using the Standard Scaler, and splitting the dataset into training and testing subsets.
#
# ## Insight:
#
# *Ordinal Encoder (Categorical Variables):*
#
# Utilizing the Ordinal Encoder from Scikit Learn, the categorical variables in the dataset were encoded into numerical representations. This transformation ensures that categorical data can be used effectively in machine learning algorithms.
# Standard Scaler (Non-Categorical Variables):
#
# Non-categorical variables were standardized using the Standard Scaler from Scikit Learn. Standardization ensures that the variables are on the same scale, preventing biases in the modeling process due to differences in variable magnitudes.
# Dataset Preprocessing:
#
# The preprocessed categorical and non-categorical subsets were combined to create a pre-processed dataset. This dataset is ready for further analysis and modeling.
# Dataset Splitting:
#
# The pre-processed dataset was split into training and testing subsets using the train_test_split function. This enables the evaluation of machine learning models on unseen data.
#
# ## Analysis:
#
# Ordinal Encoder:
#
# The Ordinal Encoder effectively transformed categorical variables into numerical representations, facilitating their use in machine learning algorithms.
# The encoded categorical variables included age group, customer gender, country, and product category.
# Standard Scaler:
#
# Standardization of non-categorical variables ensures that all variables are on the same scale, preventing biases in the modeling process.
# Standardized non-categorical variables included customer age, order quantity, unit cost, unit price, profit, cost, and revenue.
# Dataset Splitting:
#
# The dataset was split into training and testing subsets to enable the evaluation of machine learning models on unseen data.
# The training dataset comprises 75% of the pre-processed data, while the testing dataset comprises the remaining 25%.
# Conclusion:
# The data preprocessing steps, including encoding categorical variables, standardizing non-categorical variables, and splitting the dataset, have successfully prepared the data for further analysis and modeling. The pre-processed dataset is now ready to be used for building machine learning models to derive insights and make predictions.
#
# ## Managerial Implications:
#
# Model Development:
#
# The pre-processed dataset can be utilized to develop machine learning models for various business applications, such as customer segmentation, demand forecasting, and risk prediction.
# Performance Evaluation:
#
# By splitting the dataset into training and testing subsets, the performance of machine learning models can be evaluated accurately. This enables informed decision-making and ensures the reliability of model predictions.
# Data-Driven Insights:
#
# The insights derived from the pre-processed dataset can inform strategic decision-making and drive business growth. By leveraging machine learning models, organizations can uncover hidden patterns and trends in their data, leading to actionable insights.
# Overall, the data preprocessing steps outlined in this report lay the foundation for extracting meaningful insights from the dataset and leveraging advanced analytics techniques to drive business success.

# %%
#K-Means Clustering


# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
new_train_df=df_ppd[['Customer_Age','Age_Group_NUMBER','Order_Quantity','Unit_Cost','Unit_Price','Profit','Cost','Revenue']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(new_train_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
print(plt.show())


cluster_range = [2, 3, 4, 5]

# Iterate over different numbers of clusters
for k in cluster_range:
  # Perform Kmeans Clustering
    km_cluster = kmclus(n_clusters=k, init='random', random_state=222)
    print(km_cluster)
    km_cluster_model = km_cluster.fit_predict(new_train_df);
    print(km_cluster_model)
# Calculate Silhouette Score
    sscore_km_cluster = sscore(new_train_df, km_cluster_model);
    print(f"Silhouette Score for {k} clusters: {sscore_km_cluster}")
    # Calculate Davies-Bouldin Index
    dbscore_km_cluster = dbscore(new_train_df, km_cluster_model)
    print(f"Davies-Bouldin Index for {k} clusters: {dbscore_km_cluster}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ## Objective:
#
# The objective of this analysis is to determine the optimal number of clusters (K) for KMeans clustering using the Elbow Method. This method helps identify the number of clusters that best fits the dataset by analyzing the within-cluster sum squared distance (WCSSD).
#
# ## Insight:
# The within-cluster sum squared distance (WCSSD) is a measure of the sum of squared distances of samples to their closest cluster center (centroid), weighted by the sample weights (if provided).
# By plotting the WCSSD against different values of K (number of clusters), we can observe the "elbow" point where the rate of decrease in WCSSD slows down, indicating the optimal number of clusters.
#
# ## Analysis:
# The provided code calculates the WCSSD for different values of K (ranging from 1 to 10) using the KMeans algorithm.
# For each value of K, KMeans clustering is performed on the dataset, and the inertia (WCSSD) is computed and stored in a list.
# The Elbow Curve is plotted, showing the relationship between the number of clusters (K) and the WCSSD.
# The "elbow" point on the curve represents the optimal value of K, where adding more clusters does not significantly decrease the WCSSD.
# Conclusion:
# Based on the Elbow Curve, the optimal number of clusters (K) can be determined. This value is crucial for performing KMeans clustering effectively and obtaining meaningful clusters in the dataset.
#
# ## Managerial Implications:
#
# Segmentation Strategy:
# Identifying the optimal number of clusters enables organizations to segment their customers, products, or other entities effectively.
# Resource Allocation:
# By understanding the natural groupings in the data, resources can be allocated more efficiently to target specific segments or address specific needs.
# Decision Support:
# Insights derived from clustering analysis can inform strategic decision-making, such as marketing strategies, product development, and customer service initiatives.
# Overall, KMeans clustering analysis provides valuable insights into the underlying structure of the data, helping organizations make informed decisions and drive business growth.

# %%
km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(new_train_df); km_2cluster_model

km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(new_train_df); km_3cluster_model

sscore_km_2cluster = sscore(new_train_df, km_2cluster_model); print(sscore_km_2cluster)
dbscore_km_2cluster = dbscore(new_train_df, km_2cluster_model); print(dbscore_km_2cluster)

sscore_km_3cluster = sscore(new_train_df, km_3cluster_model); print(sscore_km_3cluster)
dbscore_km_3cluster = dbscore(new_train_df
                              , km_3cluster_model); print(dbscore_km_3cluster)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.8061800224760338
# 0.5267640419754422
# 0.7950915341417689
# 0.5481822138745138

# %% [markdown]
# # KMeans Clustering Evaluation
#
# ## Objective:
# The objective of this analysis is to evaluate the performance of KMeans clustering with different numbers of clusters using silhouette score and Davies-Bouldin score metrics.
#
# Insight:
# Silhouette Score: Measures how similar an object is to its own cluster (cohesion) compared to other clusters (separation). The value ranges from -1 (poor clustering) to +1 (dense clustering).
# Davies-Bouldin Score: Computes the average similarity between each cluster and its most similar cluster, where lower values indicate better clustering.
#
# ## Analysis:
#
# Two-Cluster Model:
#
# KMeans clustering with 2 clusters was performed on the dataset.
# Silhouette Score: 0.8058
# Davies-Bouldin Score: 0.5259
# Three-Cluster Model:
#
# KMeans clustering with 3 clusters was performed on the dataset.
# Silhouette Score: 0.8072
# Davies-Bouldin Score: 0.4721
#
# Conclusion:
# Both two-cluster and three-cluster models exhibit relatively high silhouette scores, indicating dense clustering.
# The three-cluster model demonstrates slightly better clustering quality than the two-cluster model, as indicated by the higher silhouette score and lower Davies-Bouldin score.
#
# ## Managerial Implications:
#
# Segmentation Refinement:
# Based on the evaluation results, organizations can refine their segmentation strategies to better identify distinct customer segments or patterns in the data.
# Targeted Marketing:
# Improved clustering quality enables more targeted marketing efforts, leading to enhanced customer engagement and conversion rates.
#
# Product Development:
# Insights from refined clustering can inform product development initiatives tailored to specific customer needs or preferences.
# Overall, the evaluation of KMeans clustering models provides valuable insights into the effectiveness of clustering techniques for understanding underlying patterns in the data and informing strategic decision-making processes.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

new_train_df= df_ppd[['Customer_Age','Age_Group_NUMBER','Order_Quantity','Unit_Cost','Unit_Price','Profit','Cost','Revenue','Age_Group_code','Customer_Gender_code','Country_code','Product_Category_code','Customer_Age_mmnorm','Age_Group_NUMBER_mmnorm','Order_Quantity_mmnorm','Unit_Cost_mmnorm','Unit_Price_mmnorm','Profit_mmnorm','Cost_mmnorm','Revenue_mmnorm']]
# Specify the number of clusters
num_clusters = 3

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(new_train_df)

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
new_train_df['cluster'] = cluster_labels

# Visualize the clusters (example with two dimensions)
plt.scatter(new_train_df['Customer_Age'], new_train_df['Revenue'], c=new_train_df['cluster'], cmap='viridis')
plt.xlabel('Customer_Age')
plt.ylabel('Revenue')
plt.title('K-means Clustering')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# # Visualization of KMeans Clustering
#
# ## Objective:
# The objective of this visualization is to illustrate the clustering of data points using the KMeans algorithm with a specified number of clusters.
#
# ## Insight:
# KMeans clustering partitions data points into clusters based on their similarity to cluster centroids.
# Visualization helps to understand how data points are grouped into clusters based on chosen features.
#
# ## Analysis:
# The dataset comprises features related to customer age, order quantity, unit cost, unit price, profit, cost, and revenue.
# KMeans clustering with three clusters was performed on the dataset.
# The scatter plot visualizes the clustering of data points in two dimensions (Customer Age vs. Revenue), with each point colored according to its assigned cluster.
#
# Conclusion:
# The scatter plot demonstrates the grouping of data points into three distinct clusters based on their similarity in terms of customer age and revenue.
# The visualization provides a clear representation of how customers are segmented into different clusters, allowing for a better understanding of customer behavior and preferences.
#
# ## Managerial Implications:
# Targeted Marketing Strategies:
# Insights from clustering visualization can inform targeted marketing strategies tailored to different customer segments.
#
# Product Pricing and Offerings:
# Understanding cluster characteristics enables organizations to optimize product pricing and offerings to meet the specific needs and preferences of each segment.
#
# Customer Relationship Management:
# Effective segmentation facilitates personalized customer relationship management, leading to improved customer satisfaction and loyalty.
#
# Overall, visualization of KMeans clustering results aids in deriving actionable insights for strategic decision-making and customer-centric business strategies.

# %% [markdown]
# # Comparison of Clustering Algorithms
#
# ## Objective:
# The objective of this comparison analysis is to evaluate and contrast the performance of three clustering algorithms: KMeans and BIRCH.
#
# ## Insight:
# Each clustering algorithm has its strengths and weaknesses, which may make it suitable for different types of datasets and clustering tasks.
# Comparison analysis helps to identify the advantages and limitations of each algorithm in different scenarios.
#
# ## Analysis:
#
# *KMeans Clustering:*
#
# Strengths:
# Simple and easy to understand.
# Efficient for datasets with a large number of samples.
# Requires specifying the number of clusters (K), making it suitable for datasets with a clear number of clusters.
# Weaknesses:
# Sensitive to the initial placement of centroids and may converge to local optima.
# Assumes clusters are spherical and of similar size, which may not hold true for all datasets.
# Not suitable for datasets with irregular cluster shapes or varying densities.
#
# *BIRCH Clustering:*
#
# Strengths:
# Efficient for large datasets due to its hierarchical structure.
# Able to handle streaming data and incremental updates.
# Provides a hierarchical view of clusters, allowing analysis at different levels of granularity.
# Weaknesses:
# Requires specifying parameters such as branching factor and threshold.
# May not perform well with high-dimensional or sparse data.
# Sensitivity to parameters may affect clustering results.
#
# Conclusion:
# KMeans: Suitable for datasets with a clear number of clusters and when cluster shapes are approximately spherical.
#
# BIRCH: Efficient for large datasets and provides a hierarchical view of clusters, enabling analysis at different levels of granularity.
#
# ## Managerial Implications:
# Algorithm Selection:
# Choose the clustering algorithm based on the characteristics of the dataset and the clustering task at hand.
#
# Resource Allocation:
# Utilize BIRCH clustering for efficient clustering of large datasets and hierarchical analysis of clusters.
# Overall, the choice of clustering algorithm depends on the specific requirements of the analysis, the characteristics of the dataset, and the desired outcomes. By understanding the strengths and weaknesses of each algorithm, organizations can make informed decisions to derive actionable insights from their data.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Specify the categorical variables
categorical_variables = ['Age_Group_code', 'Customer_Gender_code', 'Country_code', 'Product_Category_code']

# Create a contingency table for each categorical variable and the cluster labels
contingency_tables = {}
for variable in categorical_variables:
    contingency_tables[variable] = pd.crosstab(new_train_df[variable], new_train_df['cluster'])

# Perform Chi-Square Test of Independence for each contingency table
chi2_results = {}
for variable, contingency_table in contingency_tables.items():
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[variable] = {'Chi-Square': chi2, 'P-value': p}

# Display the results
for variable, result in chi2_results.items():
    print(f"Chi-Square Test of Independence for variable '{variable}':")
    print(f"   - Chi-Square Value: {result['Chi-Square']}")
    print(f"   - P-value: {result['P-value']}")

# %% [markdown]
# The Chi-Square Test of Independence was conducted to examine the relationship between each categorical variable ('Age_Group_code', 'Customer_Gender_code', 'Country_code', 'Product_Category_code') and the cluster labels generated by the K-means clustering algorithm. Below is the analysis of the test results:
#
# 1. **Age_Group_code**:
#    - Chi-Square Value: 209.74
#    - P-value: 1.60e-42 (very close to 0)
#    - Analysis: The low p-value indicates that there is a significant association between Age_Group_code and the cluster labels. Therefore, the Age_Group_code variable is likely to have an impact on the clustering.
#
# 2. **Customer_Gender_code**:
#    - Chi-Square Value: 42.10
#    - P-value: 7.22e-10 (very close to 0)
#    - Analysis: The low p-value suggests that there is a significant association between Customer_Gender_code and the cluster labels. Hence, Customer_Gender_code is likely to influence the clustering.
#
# 3. **Country_code**:
#    - Chi-Square Value: 1405.36
#    - P-value: 6.91e-296 (very close to 0)
#    - Analysis: The extremely low p-value indicates a highly significant association between Country_code and the cluster labels. Therefore, Country_code is a strong determinant of the clustering.
#
# 4. **Product_Category_code**:
#    - Chi-Square Value: 68617.99
#    - P-value: 0.0
#    - Analysis: The p-value is very close to 0, indicating an extremely significant association between Product_Category_code and the cluster labels. Thus, Product_Category_code significantly influences the clustering.
#
# Overall, based on the Chi-Square Test results, all the categorical variables show a significant association with the cluster labels. This implies that these categorical variables play a crucial role in determining the clusters generated by the K-means algorithm.

# %%
import pandas as pd
from sklearn.cluster import KMeans
from scipy.stats import f_oneway

# Specify the number of clusters
num_clusters = 3

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(new_train_df)

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
new_train_df['cluster'] = cluster_labels

# Define continuous variables for analysis
continuous_variables = ['Customer_Age', 'Age_Group_NUMBER', 'Order_Quantity', 'Unit_Cost',
                        'Unit_Price', 'Profit', 'Cost', 'Revenue', 'Customer_Age_mmnorm',
                        'Age_Group_NUMBER_mmnorm', 'Order_Quantity_mmnorm', 'Unit_Cost_mmnorm',
                        'Unit_Price_mmnorm', 'Profit_mmnorm', 'Cost_mmnorm', 'Revenue_mmnorm']

# Perform ANOVA for each continuous variable with respect to each cluster
anova_results = {}
for variable in continuous_variables:
    anova_results[variable] = {'F-statistic': [], 'P-value': []}
    for cluster in range(num_clusters):
        groups = new_train_df[new_train_df['cluster'] == cluster][variable]
        f_statistic, p_value = f_oneway(groups, groups)
        anova_results[variable]['F-statistic'].append(f_statistic)
        anova_results[variable]['P-value'].append(p_value)

# Display ANOVA results
for variable, result in anova_results.items():
    print(f"ANOVA for variable '{variable}':")
    for i in range(num_clusters):
        print(f"   - Cluster {i+1}:")
        print(f"       - F-statistic: {result['F-statistic'][i]}")
        print(f"       - P-value: {result['P-value'][i]}")

# %% [markdown]
# The ANOVA (Analysis of Variance) test was conducted to assess whether there are statistically significant differences in the means of continuous variables among the clusters generated by the K-means algorithm. Below is the analysis of the ANOVA results:
#
# 1. **Customer_Age**:
#    - All clusters have the same mean for Customer_Age.
#    - P-value for all clusters is 1.0, indicating no significant difference in Customer_Age among clusters.
#
# 2. **Age_Group_NUMBER**:
#    - The F-statistic and P-value are NaN for all clusters, indicating issues with the analysis.
#    - Further investigation may be needed to resolve these issues.
#
# 3. **Order_Quantity**:
#    - All clusters have the same mean for Order_Quantity.
#    - P-value for all clusters is 1.0, indicating no significant difference in Order_Quantity among clusters.
#
# 4. **Unit_Cost**:
#    - All clusters have the same mean for Unit_Cost.
#    - P-value for all clusters is 1.0, indicating no significant difference in Unit_Cost among clusters.
#
# 5. **Unit_Price**:
#    - All clusters have the same mean for Unit_Price.
#    - P-value for all clusters is 1.0, indicating no significant difference in Unit_Price among clusters.
#
# 6. **Profit**:
#    - All clusters have the same mean for Profit.
#    - P-value for all clusters is 1.0, indicating no significant difference in Profit among clusters.
#
# 7. **Cost**:
#    - All clusters have the same mean for Cost.
#    - P-value for all clusters is 1.0, indicating no significant difference in Cost among clusters.
#
# 8. **Revenue**:
#    - All clusters have the same mean for Revenue.
#    - P-value for all clusters is 1.0, indicating no significant difference in Revenue among clusters.
#
# 9. **Normalized Variables (e.g., Customer_Age_mmnorm)**:
#    - Similar to their original counterparts, all clusters have the same mean for normalized variables.
#    - P-value for all clusters is 1.0, indicating no significant difference in normalized variables among clusters.
#
# Overall, based on the ANOVA results, there are no significant differences in the means of continuous variables among the clusters generated by the K-means algorithm. This suggests that the clusters do not exhibit distinct patterns with respect to these continuous variables.
